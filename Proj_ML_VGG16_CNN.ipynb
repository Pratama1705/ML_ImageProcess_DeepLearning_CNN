# %% [markdown]
# ### Membagi data train dan data testing

# %%
import splitfolders

# Menentukan folder awal dari dataset citra
base_dir = './Dataset/Original_Dataset'

# Melakukan split data berdasarkan ukuran 80% dan 20%
splitfolders.ratio(base_dir, output='./Dataset', seed=1337, ratio=(.8, .2))
# Out:
# Copying files: 5080 files [00:35, 141.76 files/s]

# %% [markdown]
# ### Menentukan preproses dan scaling data

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Menentukan scalling dan perubahan setiap data train
train_datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=20,
                    horizontal_flip=True,
                    shear_range = 0.2,
                    fill_mode = 'wrap'
                )

# Menentukan scalling dan perubahan setiap data test
test_datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=20,
                    horizontal_flip=True,
                    shear_range = 0.2,
                    fill_mode = 'wrap'
                )

# %% [markdown]
# ### Menerapkan citra dengan auto labeling berdasarkan nama folder

# %%
train_dir = './Dataset/train'
validation_dir = './Dataset/val'

train_generator = train_datagen.flow_from_directory(
        train_dir,  # Direktori data latih
        target_size=(150, 150),  # Mengubah resolusi seluruh gambar menjadi 150x150 piksel
        batch_size=32,
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir, # direktori data validasi
        target_size=(150, 150), # mengubah resolusi seluruh gambar menjadi 150x150 piksel
        batch_size=32,
        class_mode='categorical')
# Out:
# Found 4063 images belonging to 3 classes.
# Found 1017 images belonging to 3 classes.

# %% [markdown]
# ### Membuat Model CNN

# %%
# import tensorflow as tf
from tensorflow.keras.applications.vgg16 import VGG16

modelCNN_VGG = VGG16(input_shape=(150, 150, 3), include_top=False, weights='imagenet')
modelCNN_VGG

# %%
for layer in modelCNN_VGG.layers :
    layer.trainable = False

# %% [markdown]
# ### Model Summary CNN VGG16

# %%
modelCNN_VGG.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ### Membuat MLP Model

# %%
from tensorflow.keras import layers
from tensorflow.keras.models import Model

# Flatten the output layer to 1 dimension
x = layers.Flatten()(modelCNN_VGG.output)

# Add a fully connected layer with 512 hidden units and ReLU activation
x = layers.Dense(128, activation='relu')(x)

# Add a final sigmoid layer with 3 node for classification output
x = layers.Dense(3, activation='softmax')(x)

modelCNN_VGG = Model(inputs=modelCNN_VGG.input, outputs=x)

# %% [markdown]
# ### Model CNN VGG16 MLP Compile

# %%
import tensorflow as tf

# categorical_crossentropy --> Digunakan untuk citra yang lebih dari 3 class
# tf.optimizers.Adam() --> Cocok untuk citra dengan data yang cukup banyak

modelCNN_VGG.compile(optimizer=tf.optimizers.Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Model CNN VGG16 Summary

# %%
modelCNN_VGG.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1048704
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 15,763,779
# Trainable params: 1,049,091
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ### Latih Model CNN

# %%
history = modelCNN_VGG.fit(
        train_generator,
        steps_per_epoch=40,  # Batch yang akan dieksekusi pada setiap epoch
        epochs=50,
        validation_data=validation_generator, # Menampilkan akurasi pengujian data validasi
        validation_steps=10,  # Batch yang akan dieksekusi pada setiap epoch
        batch_size=100,
        verbose=1 # Animasi perjalanan epoch
    )
# Out:
# Epoch 1/50
# 40/40 [==============================] - 145s 4s/step - loss: 0.3879 - accuracy: 0.8594 - val_loss: 0.0858 - val_accuracy: 0.9688
# Epoch 2/50
# 40/40 [==============================] - 134s 3s/step - loss: 0.0593 - accuracy: 0.9875 - val_loss: 0.0392 - val_accuracy: 0.9906
# Epoch 3/50
# 40/40 [==============================] - 155s 4s/step - loss: 0.0356 - accuracy: 0.9930 - val_loss: 0.0237 - val_accuracy: 0.9969
# Epoch 4/50
# 40/40 [==============================] - 159s 4s/step - loss: 0.0241 - accuracy: 0.9930 - val_loss: 0.0147 - val_accuracy: 0.9969
# Epoch 5/50
# 40/40 [==============================] - 144s 4s/step - loss: 0.0189 - accuracy: 0.9961 - val_loss: 0.0269 - val_accuracy: 0.9937
# Epoch 6/50
# 40/40 [==============================] - 122s 3s/step - loss: 0.0127 - accuracy: 0.9992 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 7/50
# 40/40 [==============================] - 137s 3s/step - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.0111 - val_accuracy: 0.9969
# Epoch 8/50
# 40/40 [==============================] - 178s 4s/step - loss: 0.0201 - accuracy: 0.9922 - val_loss: 0.0078 - val_accuracy: 0.9969
# Epoch 9/50
# 40/40 [==============================] - 160s 4s/step - loss: 0.0088 - accuracy: 0.9977 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 10/50
# 40/40 [==============================] - 131s 3s/step - loss: 0.0067 - accuracy: 0.9984 - val_loss: 0.0137 - val_accuracy: 0.9969
# Epoch 11/50
# 40/40 [==============================] - 146s 4s/step - loss: 0.0131 - accuracy: 0.9953 - val_loss: 0.0059 - val_accuracy: 0.9969
# Epoch 12/50
# 40/40 [==============================] - 140s 4s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 13/50
# 40/40 [==============================] - 151s 4s/step - loss: 0.0068 - accuracy: 0.9977 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 14/50
# 40/40 [==============================] - 151s 4s/step - loss: 0.0065 - accuracy: 0.9977 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 15/50
# 40/40 [==============================] - 142s 4s/step - loss: 0.0126 - accuracy: 0.9961 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 16/50
# 40/40 [==============================] - 147s 4s/step - loss: 0.0083 - accuracy: 0.9984 - val_loss: 0.0260 - val_accuracy: 0.9937
# Epoch 17/50
# 40/40 [==============================] - 145s 4s/step - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 18/50
# 40/40 [==============================] - 137s 3s/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 5.2059e-04 - val_accuracy: 1.0000
# Epoch 19/50
# 40/40 [==============================] - 152s 4s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 0.9969
# Epoch 20/50
# 40/40 [==============================] - 147s 4s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9969
# Epoch 21/50
# 40/40 [==============================] - 152s 4s/step - loss: 0.0094 - accuracy: 0.9961 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 22/50
# 40/40 [==============================] - 121s 3s/step - loss: 0.0048 - accuracy: 0.9992 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 23/50
# 40/40 [==============================] - 120s 3s/step - loss: 0.0045 - accuracy: 0.9984 - val_loss: 0.0132 - val_accuracy: 0.9969
# Epoch 24/50
# 40/40 [==============================] - 168s 4s/step - loss: 7.9547e-04 - accuracy: 1.0000 - val_loss: 5.5272e-04 - val_accuracy: 1.0000
# Epoch 25/50
# 40/40 [==============================] - 189s 5s/step - loss: 8.1798e-04 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9969
# Epoch 26/50
# 40/40 [==============================] - 172s 4s/step - loss: 8.1118e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 27/50
# 40/40 [==============================] - 161s 4s/step - loss: 9.6402e-04 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9969
# Epoch 28/50
# 40/40 [==============================] - 168s 4s/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 29/50
# 40/40 [==============================] - 142s 4s/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0051 - val_accuracy: 0.9969
# Epoch 30/50
# 40/40 [==============================] - 117s 3s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 0.9969
# Epoch 31/50
# 40/40 [==============================] - 138s 3s/step - loss: 0.0041 - accuracy: 0.9992 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 32/50
# 40/40 [==============================] - 146s 4s/step - loss: 6.2154e-04 - accuracy: 1.0000 - val_loss: 6.3158e-04 - val_accuracy: 1.0000
# Epoch 33/50
# 40/40 [==============================] - 146s 4s/step - loss: 3.3541e-04 - accuracy: 1.0000 - val_loss: 8.8634e-04 - val_accuracy: 1.0000
# Epoch 34/50
# 40/40 [==============================] - 135s 3s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.8003e-04 - val_accuracy: 1.0000
# Epoch 35/50
# 40/40 [==============================] - 101s 3s/step - loss: 6.2603e-04 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 0.9969
# Epoch 36/50
# 40/40 [==============================] - 114s 3s/step - loss: 2.7795e-04 - accuracy: 1.0000 - val_loss: 1.6016e-04 - val_accuracy: 1.0000
# Epoch 37/50
# 40/40 [==============================] - 147s 4s/step - loss: 7.3940e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 38/50
# 40/40 [==============================] - 169s 4s/step - loss: 3.2279e-04 - accuracy: 1.0000 - val_loss: 4.5267e-04 - val_accuracy: 1.0000
# Epoch 39/50
# 40/40 [==============================] - 133s 3s/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.0057 - val_accuracy: 0.9969
# Epoch 40/50
# 40/40 [==============================] - 118s 3s/step - loss: 0.0052 - accuracy: 0.9977 - val_loss: 3.8379e-04 - val_accuracy: 1.0000
# Epoch 41/50
# 40/40 [==============================] - 145s 4s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 42/50
# 40/40 [==============================] - 160s 4s/step - loss: 2.4954e-04 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 0.9937
# Epoch 43/50
# 40/40 [==============================] - 129s 3s/step - loss: 3.9020e-04 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9969
# Epoch 44/50
# 40/40 [==============================] - 117s 3s/step - loss: 3.8349e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 45/50
# 40/40 [==============================] - 146s 4s/step - loss: 3.0378e-04 - accuracy: 1.0000 - val_loss: 1.0901e-04 - val_accuracy: 1.0000
# Epoch 46/50
# 40/40 [==============================] - 163s 4s/step - loss: 9.0590e-04 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 0.9969
# Epoch 47/50
# 40/40 [==============================] - 143s 4s/step - loss: 3.4392e-04 - accuracy: 1.0000 - val_loss: 4.7747e-04 - val_accuracy: 1.0000
# Epoch 48/50
# 40/40 [==============================] - 115s 3s/step - loss: 1.3272e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9969
# Epoch 49/50
# 40/40 [==============================] - 139s 3s/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.0152 - val_accuracy: 0.9937
# Epoch 50/50
# 40/40 [==============================] - 162s 4s/step - loss: 0.0099 - accuracy: 0.9977 - val_loss: 1.9791e-04 - val_accuracy: 1.0000

# %% [markdown]
# ### Evaluate Model

# %%
import matplotlib.pyplot as plt

# Akurasi
accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

# Loss
loss = history.history['loss']
validation_loss = history.history['val_loss']

# Jumlah epoch
epochs_range = range(len(history.history['accuracy']))

# Plotting metrics
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend()
plt.title('Training and Validation Loss')

plt.show()

# %% [markdown]
# ### Testing Model

# %%
import matplotlib.pyplot as plt

# Backgroung hijau
img_paper_1 = plt.imread('./Dataset/Testing_Model/1fKclJk4eBWOQSR1.png')
img_rock_1 = plt.imread('./Dataset/Testing_Model/1mnAKQCHEDbtjPX2.png')
img_scissors_1 = plt.imread('./Dataset/Testing_Model/1L1n6plr7jlZGirw.png')

# Backgroung putih
img_paper_2 = plt.imread('./Dataset/Testing_Model/paper-hires1.png')
img_rock_2 = plt.imread('./Dataset/Testing_Model/rock-hires1.png')
img_scissors_2 = plt.imread('./Dataset/Testing_Model/scissors-hires1.png')

# Tangan sendiri
img_paper_3 = plt.imread('./Dataset/Testing_Model/paper-sendiri.jpeg')
img_rock_3 = plt.imread('./Dataset/Testing_Model/rock-sendiri.jpeg')
img_scissors_3 = plt.imread('./Dataset/Testing_Model/scissors-sendiri.jpeg')

plt.figure(figsize=(15, 7))

plt.subplot(3, 3, 1)
plt.imshow(img_paper_1)
plt.title('Paper')

plt.subplot(3, 3, 2)
plt.imshow(img_rock_1)
plt.title('Rock')

plt.subplot(3, 3, 3)
plt.imshow(img_scissors_1)
plt.title('Scissors')

plt.subplot(3, 3, 4)
plt.imshow(img_paper_2)

plt.subplot(3, 3, 5)
plt.imshow(img_rock_2)

plt.subplot(3, 3, 6)
plt.imshow(img_scissors_2)

plt.subplot(3, 3, 7)
plt.imshow(img_paper_3)

plt.subplot(3, 3, 8)
plt.imshow(img_rock_3)

plt.subplot(3, 3, 9)
plt.imshow(img_scissors_3)

plt.show()

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

def convertImage(img) :
    gambar = image.load_img(img, target_size=(150, 150))
    gambar_array = image.img_to_array(gambar)
    gambar_batch = np.expand_dims(gambar_array, axis=0)
    gambar_preproses = np.vstack([gambar_batch])

    return gambar_preproses

# %%
# Backgroung hijau
img_paper_1 = './Dataset/Testing_Model/1fKclJk4eBWOQSR1.png'
img_rock_1 = './Dataset/Testing_Model/1mnAKQCHEDbtjPX2.png'
img_scissors_1 = './Dataset/Testing_Model/1L1n6plr7jlZGirw.png'

# Backgroung putih
img_paper_2 = './Dataset/Testing_Model/paper-hires1.png'
img_rock_2 = './Dataset/Testing_Model/rock-hires1.png'
img_scissors_2 = './Dataset/Testing_Model/scissors-hires1.png'

# Tangan sendiri
img_paper_3 = './Dataset/Testing_Model/paper-sendiri.jpeg'
img_rock_3 = './Dataset/Testing_Model/rock-sendiri.jpeg'
img_scissors_3 = './Dataset/Testing_Model/scissors-sendiri.jpeg'

prediction = modelCNN_VGG.predict(convertImage(img_rock_1), batch_size=10)
output_class = np.argmax(prediction)

if output_class == 0:
    print('Paper')
elif output_class == 1:
    print('Rock')
else:
    print('Scissors')
# Out:
# Rock
