# %%
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
# datagen = ImageDataGenerator(
#                     rescale=1./255,
#                     rotation_range=20,
#                     horizontal_flip=True,
#                     shear_range = 0.2,
#                     fill_mode = 'wrap'
#                 )

# %% [markdown]
# ### Load Citra

# %%
# load the image
img = load_img('./Dataset/Testing_Model/paper-hires1.png')

# convert to numpy array
data = img_to_array(img)

# expand dimension to one sample
samples = expand_dims(data, 1)

# %% [markdown]
# ### Rotasi

# %%
datagen = ImageDataGenerator(rotation_range=75)

# prepare iterator
it = datagen.flow(samples, batch_size=1)

for i in range(9):
    	# define subplot
	plt.subplot(330 + 1 + i)
	
	# generate batch of images
	batch = it.next()
	
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	
	# plot raw pixel data
	plt.imshow(image)

# show the figure
plt.show()

# %% [markdown]
# ### Horizontal Flip

# %%
datagen = ImageDataGenerator(horizontal_flip=True)

# prepare iterator
it = datagen.flow(samples, batch_size=1)

for i in range(9):
    	# define subplot
	plt.subplot(330 + 1 + i)
	
	# generate batch of images
	batch = it.next()
	
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	
	# plot raw pixel data
	plt.imshow(image)

# show the figure
plt.show()

# %% [markdown]
# ### Vertical Flip

# %%
datagen = ImageDataGenerator(vertical_flip=True)

# prepare iterator
it = datagen.flow(samples, batch_size=1)

for i in range(9):
    	# define subplot
	plt.subplot(330 + 1 + i)
	
	# generate batch of images
	batch = it.next()
	
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	
	# plot raw pixel data
	plt.imshow(image)

# show the figure
plt.show()

# %% [markdown]
# ### Shear Range

# %%
datagen = ImageDataGenerator(shear_range = 1.0)

# prepare iterator
it = datagen.flow(samples, batch_size=1)

for i in range(9):
    	# define subplot
	plt.subplot(330 + 1 + i)
	
	# generate batch of images
	batch = it.next()
	
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	
	# plot raw pixel data
	plt.imshow(image)

# show the figure
plt.show()

# %% [markdown]
# ### Rescale

# %%
datagen = ImageDataGenerator(rescale=1/255)

# prepare iterator
it = datagen.flow(samples, batch_size=1)

for i in range(9):
    	# define subplot
	plt.subplot(330 + 1 + i)
	
	# generate batch of images
	batch = it.next()
	
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	
	# plot raw pixel data
	plt.imshow(image)

# show the figure
plt.show()

# %%
datagen = ImageDataGenerator(
	fill_mode = 'reflect',
)

# prepare iterator
it = datagen.flow(samples, batch_size=1)

for i in range(9):
    	# define subplot
	plt.subplot(330 + 1 + i)
	
	# generate batch of images
	batch = it.next()
	
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	
	# plot raw pixel data
	plt.imshow(image)

# show the figure
plt.show()
